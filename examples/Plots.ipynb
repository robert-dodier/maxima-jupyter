# %% [markdown]
# The examples in this notebook were taken from the Maxima documentation.
#
# # Standard Plots
#
# First set the default plot options to SVG output so that Maxima-Jupyter can capture the output.

# %%
set_plot_option([svg_file, "maxplot.svg"]);
# Out:
# (%o9) [[svg_file, maxplot.svg], [plot_format, gnuplot], [grid, 30, 30],
# [run_viewer, true], [axes, true], [nticks, 29], [adapt_depth, 5],
# [color, blue, red, green, magenta, black, cyan],
# [point_type, bullet, box, triangle, plus, times, asterisk],
# [palette, [gradient, green, cyan, blue, violet],
# [gradient, magenta, violet, blue, cyan, green, yellow, orange, red, brown,
# black]], [gnuplot_preamble, ], [gnuplot_term, default]]

# %% [markdown]
# ## `contour_plot` Example

# %%
contour_plot (x^2 + y^2, [x, -4, 4], [y, -4, 4])$
# Out:
# contour_plot is now obsolete. Using plot2d instead:
# plot2d ([contour, y^2+x^2], [x,-4,4], [y,-4,4])
# /tmp/maxplot.svg

# %% [markdown]
# ## `julia` Example

# %%
julia (-0.55, 0.6, [iterations, 36], [x, -0.3, 0.2],
      [y, 0.3, 0.9], [grid, 400, 400], [color_bar_tics, 0, 6, 36])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# ## `mandelbrot` Example

# %%
mandelbrot ([iterations, 30], [x, -2, 1], [y, -1.2, 1.2],
            [grid,400,400]);
# Out:
# /tmp/maxplot.svg
# (%o12)           [/tmp/maxout163803.gnuplot, /tmp/maxplot.svg]

# %% [markdown]
# ## `plot2d` Example

# %%
plot2d (sin(x), [x, -%pi, %pi])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# ## `plot3d` Example

# %%
plot3d (u^2 - v^2, [u, -2, 2], [v, -3, 3], [grid, 100, 100],
        [mesh_lines_color,false])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# # `draw` Plots
# First load the `draw` package and set the default terminal to `svg`.

# %%
load("draw")$
set_draw_defaults(file_name="maxplot.svg",terminal='svg)$
# Out:
# ; processing (DEFVAR $DRAW_RENDERER ...)
# ; processing (DEFVAR $DRAW_USE_PNGCAIRO ...)
# ; processing (DEFVAR *USER-GR-DEFAULT-OPTIONS* ...)
# ; processing (DEFUN $SET_DRAW_DEFAULTS ...)
# ; processing (DEFUN USER-DEFAULTS ...)
# ; processing (DEFVAR *ALLOCATIONS* ...)
# ; processing (DEFVAR *GR-OPTIONS* ...)
# ; processing (DEFUN INI-GR-OPTIONS ...)
# ; processing (DEFUN GET-OPTION ...)
# ; processing (DEFUN ATOM-TO-DOWNCASED-STRING ...)
# ; processing (DEFVAR *COLOR-TABLE* ...)
# ; processing (SETF (GETHASH "snow" ...) ...)
# ; processing (DEFUN CORRECT-COLOR-NAME ...)
# ; processing (DEFUN CORRECT-COLOR-HEX ...)
# ; processing (DEFUN CORRECT-COLOR ...)
# ; processing (DEFUN HEX-TO-NUMERIC-LIST ...)
# ; processing (DEFUN HEX-TO-RGB ...)
# ; processing (DEFUN UPDATE-COLOR ...)
# ; processing (DEFUN UPDATE-KEY_POS ...)
# ; processing (DEFVAR *DRAW-TERMINAL-NUMBER* ...)
# ; processing (DEFUN UPDATE-TERMINAL ...)
# ; processing (DEFVAR *DRAW-TRANSFORM-DIMENSIONS* ...)
# ; processing (DEFVAR *DRAW-TRANSFORM-F1* ...)
# ; processing (DEFVAR *DRAW-TRANSFORM-F2* ...)
# ; processing (DEFVAR *DRAW-TRANSFORM-F3* ...)
# ; processing (DEFMACRO TRANSFORM-POINT ...)
# ; processing (DEFMACRO TRANSFORM-LISTS ...)
# ; processing (DEFUN UPDATE-TRANSFORM ...)
# ; processing (DEFVAR *DRAW-ENHANCED3D-TYPE* ...)
# ; processing (DEFVAR *DRAW-ENHANCED3D-FUN* ...)
# ; processing (DEFUN CHECK-ENHANCED3D-MODEL ...)
# ; processing (DEFUN UPDATE-ENHANCED3D-EXPRESSION ...)
# ; processing (DEFUN UPDATE-ENHANCED3D ...)
# ; processing (DEFVAR *DRAW-ISOLINES-TYPE* ...)
# ; processing (DEFVAR *DRAW-ISOLINES-FUN* ...)
# ; processing (DEFUN CHECK-ISOLINES-MODEL ...)
# ; processing (DEFUN UPDATE-ISOLINES-EXPRESSION ...)
# ; processing (DEFUN UPDATE-ISOLINES ...)
# ; processing (DEFUN UPDATE-CONTOUR-ISOLINES ...)
# ; processing (DEFUN UPDATE-BOOLEAN-OPTION ...)
# ; processing (DEFUN UPDATE-POSITIVE-INTEGER ...)
# ; processing (DEFUN UPDATE-POSITIVE-FLOAT ...)
# ; processing (DEFUN UPDATE-NONNEGATIVE-FLOAT ...)
# ; processing (DEFUN UPDATE-VIEW ...)
# ; processing (DEFUN UPDATE-INTERPOLATE_COLOR ...)
# ; processing (DEFUN UPDATE-ALLOCATION ...)
# ; processing (DEFUN UPDATE-DIMENSIONS ...)
# ; processing (DEFUN UPDATE-POINTTYPE ...)SB-INT:TYPE-STYLE-WARNING: This is not a
#          NUMBER:
#  NIL
# See also:
#   The SBCL Manual, Node "Handling of Types"
# ; processing (DEFUN UPDATE-STRING ...)
# ; processing (DEFUN UPDATE-OPACITY ...)
# ; processing (DEFUN UPDATE-PALETTE ...)
# ; processing (DEFUN UPDATE-LINESTYLE ...)
# ; processing (DEFUN UPDATE-POINTSJOINED ...)
# ; processing (DEFUN UPDATE-CAPPING ...)
# ; processing (DEFUN INI-LOCAL-OPTION-VARIABLES ...)
# ; processing (DEFUN INI-GLOBAL-OPTIONS ...)
# ; processing (DEFUN UPDATE-GR-OPTION ...)
# ; processing (DEFUN NEAR-EQUAL ...)
# ; processing (DEFMACRO LISTIFY-ARGUMENTS ...)
# ; processing (DEFVAR *I3D_TRIANGLES* ...)
# ; processing (DEFUN COPY-ARRAY ...)
# ; processing (DEFUN EDGE-INTERPOLATION ...)
# ; processing (DEFMACRO MAKE-TRIANGLE-VERTICES ...)
# ; processing (DEFUN FLATTEN ...)
# ; processing (DEFUN FIND-TRIANGLES ...)
# ; processing (DEFUN $DRAW ...)
# ; processing (DEFUN $DRAW2D ...)
# ; processing (DEFUN $DRAW3D ...)SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::TRANSFORM-POINT in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::TRANSFORM-LISTS in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::LISTIFY-ARGUMENTS in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::MAKE-TRIANGLE-VERTICES in DEFMACRO
# ; processing ($PUT (QUOTE $GNUPLOT) ...)
# ; processing (DEFVAR $DRAW_VERSION ...)
# ; processing (DEFUN WRITE-FONT-TYPE ...)
# ; processing (DEFVAR *MULTIPLOT-IS-ACTIVE* ...)
# ; processing (DEFUN $MULTIPLOT_MODE ...)
# ; processing (DEFMACRO UPDATE-RANGE ...)
# ; processing (DEFUN UPDATE-RANGES-2D ...)
# ; processing (DEFUN UPDATE-RANGES-3D ...)
# ; processing (DEFMACRO CHECK-EXTREMES-X ...)
# ; processing (DEFMACRO CHECK-EXTREMES-Y ...)
# ; processing (DEFMACRO CHECK-EXTREMES-Z ...)
# ; processing (DEFUN AXES-TO-PLOT ...)
# ; processing (DEFSTRUCT GR-OBJECT ...)
# ; processing (DEFUN MAKE-OBJ-TITLE ...)
# ; processing (DEFUN ERRORS ...)
# ; processing (DEFUN POINTS-COMMAND ...)
# ; processing (DEFUN POINTS-ARRAY-2D ...)
# ; processing (DEFUN POINTS-ARRAY-1D ...)
# ; processing (DEFUN POINTS-LIST ...)
# ; processing (DEFUN POINTS ...)
# ; processing (DEFUN POINTS3D-COMMAND ...)
# ; processing (DEFUN POINTS3D ...)
# ; processing (DEFUN POLYGON ...)
# ; processing (DEFUN TRIANGLE ...)
# ; processing (DEFUN QUADRILATERAL ...)
# ; processing (DEFUN RECTANGLE ...)
# ; processing (DEFUN ELLIPSE ...)
# ; processing (DEFUN REPLACE-SUBSTRING ...)
# ; processing (DEFUN LABEL ...)
# ; processing (DEFUN BARS ...)
# ; processing (DEFUN VECT ...)
# ; processing (DEFUN VECT3D ...)
# ; processing (DEFUN EXPLICIT ...)
# ; processing (DEFMACRO BUILD-POLYGON ...)
# ; processing (DEFUN REGION ...)
# ; processing (DEFUN X-ELEMENTS ...)
# ; processing (DEFUN Y-ELEMENTS ...)
# ; processing (DEFVAR PTS ...)
# ; processing (DEFUN CONTAINS-ZEROS ...)
# ; processing (DEFUN SAMPLE-DATA ...)
# ; processing (DEFUN DRAW-PRINT-SEGMENT ...)
# ; processing (DEFUN DRAW-PRINT-SQUARE ...)
# ; processing (DEFUN IMP-PL-PREPARE-FACTOR ...)
# ; processing (DEFUN IMP-PL-PREPARE-EXPR ...)
# ; processing (DEFUN IMPLICIT ...)
# ; processing (DEFUN IMPLICIT3D ...)
# ; processing (DEFUN EXPLICIT3D ...)
# ; processing (DEFUN ELEVATION_GRID ...)
# ; processing (DEFUN MESH ...)
# ; processing (DEFUN TRIANGLE3D ...)
# ; processing (DEFUN QUADRILATERAL3D ...)
# ; processing (DEFUN PARAMETRIC ...)
# ; processing (DEFUN POLAR ...)
# ; processing (DEFUN SPHERICAL ...)
# ; processing (DEFUN CYLINDRICAL ...)
# ; processing (DEFUN PARAMETRIC3D ...)
# ; processing (DEFUN PARAMETRIC_SURFACE ...)
# ; processing (DEFMACRO CHECK-TUBE-EXTREME ...)
# ; processing (DEFUN TUBE ...)
# ; processing (DEFUN IMAGE ...)
# ; processing (DEFMACRO WRITE-PALETTE-CODE ...)
# ; processing (DEFVAR *2D-GRAPHIC-OBJECTS* ...)
# ; processing (SETF (GETHASH # ...) ...)
# ; processing (DEFUN MAKE-SCENE-2D ...)
# ; processing (DEFVAR *3D-GRAPHIC-OBJECTS* ...)
# ; processing (SETF (GETHASH # ...) ...)
# ; processing (DEFUN MAKE-SCENE-3D ...)
# ; processing (DEFMACRO WRITE-SUBARRAY ...)
# ; processing (DEFUN DRAW_GNUPLOT ...)
# ; processing (DEFUN $ADD_ZEROES ...)
# ; processing (DEFUN $DRAW_FILE ...)
# ; processing (DEFUN $ACTIVATE_WINDOW ...)SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::UPDATE-RANGE in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::CHECK-EXTREMES-X in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::CHECK-EXTREMES-Y in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::CHECK-EXTREMES-Z in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::BUILD-POLYGON in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::CHECK-TUBE-EXTREME in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::WRITE-PALETTE-CODE in DEFMACRO
# SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::WRITE-SUBARRAY in DEFMACRO
# ; processing (DEFVAR *VTK-APPENDDATA-COUNTER* ...)
# ; processing (DEFVAR *VTK-EXTRACT-COUNTER* ...)
# ; processing (DEFVAR *VTK-OUTLINE-COUNTER* ...)
# ; processing (DEFVAR *VTK-POLYDATAMAPPER-COUNTER* ...)
# ; processing (DEFVAR *VTK-OUTLINEACTOR-COUNTER* ...)
# ; processing (DEFVAR *VTK-TEXTPROPERTY-COUNTER* ...)
# ; processing (DEFVAR *VTK-CUBEAXESACTOR2D-COUNTER* ...)
# ; processing (DEFVAR *VTK-CAMERA-COUNTER* ...)
# ; processing (DEFVAR *VTK-RENDERER-COUNTER* ...)
# ; processing (DEFVAR *VTK-SOURCE-COUNTER* ...)
# ; processing (DEFVAR *VTK-MAPPER-COUNTER* ...)
# ; processing (DEFVAR *VTK-ACTOR-COUNTER* ...)
# ; processing (DEFVAR *VTK-LABELACTOR-COUNTER* ...)
# ; processing (DEFVAR *VTK-TRANS-COUNTER* ...)
# ; processing (DEFVAR *VTK-FILTER-COUNTER* ...)
# ; processing (DEFVAR *VTK-FLOATARRAY-COUNTER* ...)
# ; processing (DEFVAR *VTK-DATA-FILE-COUNTER* ...)
# ; processing (DEFVAR *VTK-POINTS-COUNTER* ...)
# ; processing (DEFVAR *VTK-GLYPHPOINTS-COUNTER* ...)
# ; processing (DEFVAR *VTK-POLYDATA-COUNTER* ...)
# ; processing (DEFVAR *VTK-CELLARRAY-COUNTER* ...)
# ; processing (DEFVAR *VTK-SOLIDSOURCE-COUNTER* ...)
# ; processing (DEFVAR *VTK-TRIANGLE-COUNTER* ...)
# ; processing (DEFVAR *VTK-LABEL-COUNTER* ...)
# ; processing (DEFVAR *VTK-CHART-COUNTER* ...)
# ; processing (DEFVAR *VTK-TABLE-COUNTER* ...)
# ; processing (DEFVAR *VTK-ARRAYX-COUNTER* ...)
# ; processing (DEFVAR *VTK-ARRAYY-COUNTER* ...)
# ; processing (DEFVAR *VTK-2DKEY-COUNTER* ...)
# ; processing (DEFVAR *VTK-ISOLINES-COUNTER* ...)
# ; processing (DEFVAR *LOOKUP-TABLES* ...)
# ; processing (DEFVAR *UNITSCALE-ALREADY-DEFINED* ...)
# ; processing (DEFPARAMETER *ENHANCED3D-OR-ISOLINES-CODE* ...)
# ; processing (DEFUN GET-APPENDDATA-NAME ...)
# ; processing (DEFUN GET-EXTRACT-NAME ...)
# ; processing (DEFUN GET-OUTLINE-NAME ...)
# ; processing (DEFUN GET-OUTLINEACTOR-NAME ...)
# ; processing (DEFUN GET-TEXTPROPERTY-NAME ...)
# ; processing (DEFUN GET-CUBEAXESACTOR2D-NAME ...)
# ; processing (DEFUN GET-CAMERA-NAME ...)
# ; processing (DEFUN GET-RENDERER-NAME ...)
# ; processing (DEFUN GET-SOURCE-NAME ...)
# ; processing (DEFUN GET-MAPPER-NAME ...)
# ; processing (DEFUN GET-ACTOR-NAME ...)
# ; processing (DEFUN GET-LABELACTOR-NAME ...)
# ; processing (DEFUN GET-TRANS-NAME ...)
# ; processing (DEFUN GET-FILTER-NAME ...)
# ; processing (DEFUN GET-FLOATARRAY-NAME ...)
# ; processing (DEFUN GET-DATA-FILE-NAME ...)
# ; processing (DEFUN GET-POINTS-NAME ...)
# ; processing (DEFUN GET-GLYPHPOINTS-NAME ...)
# ; processing (DEFUN GET-POLYDATA-NAME ...)
# ; processing (DEFUN GET-CELLARRAY-NAME ...)
# ; processing (DEFUN GET-POLYDATAMAPPER-NAME ...)
# ; processing (DEFUN GET-SOLIDSOURCE-NAME ...)
# ; processing (DEFUN GET-TRIANGLE-NAME ...)
# ; processing (DEFUN GET-LABEL-NAME ...)
# ; processing (DEFUN GET-CHART-NAME ...)
# ; processing (DEFUN GET-TABLE-NAME ...)
# ; processing (DEFUN GET-ARRAYX-NAME ...)
# ; processing (DEFUN GET-ARRAYY-NAME ...)
# ; processing (DEFUN GET-ISOLINES-NAME ...)
# ; processing (DEFUN SCENEBOUNDS ...)
# ; processing (DEFUN VTKAPPENDPOLYDATA-CODE ...)
# ; processing (DEFUN VTKOUTLINEFILTER-CODE ...)
# ; processing (DEFUN VTKPOLYDATAMAPPER-CODE ...)
# ; processing (DEFUN VTKPOLYDATAMAPPER-ISOLINE-CODE ...)
# ; processing (DEFUN VTKEXTRACTPOLYDATAGEOMETRY-CODE ...)
# ; processing (DEFUN VTKTEXTPROPERTY-CODE ...)
# ; processing (DEFUN VTKCUBEAXESACTOR2D-CODE ...)
# ; processing (DEFUN VTKRENDERER3D-CODE ...)
# ; processing (DEFUN VTKRENDERER2D-CODE ...)
# ; processing (DEFUN VTKCHARTXY-CODE ...)
# ; processing (DEFUN VTKCELLARRAY-CODE ...)
# ; processing (DEFUN VTKFLOATARRAY-CODE ...)
# ; processing (DEFUN VTKGLYPH3D-CODE ...)
# ; processing (DEFUN VTKPOINTS-CODE ...)
# ; processing (DEFUN VTKTRANSFORM-CODE ...)
# ; processing (DEFUN VTKTRANSFORMFILTER-CODE ...)
# ; processing (DEFUN VTKTRANSFORMPOLYDATAFILTER-CODE ...)
# ; processing (DEFUN VTKACTOR-CODE ...)
# ; processing (DEFUN VTKACTOR-ISOLINE-CODE ...)
# ; processing (DEFUN VTKACTOR-GLYPH-CODE ...)
# ; processing (DEFUN VTKTUBEFILTER-CODE ...)
# ; processing (DEFUN VTKCONTOURFILTER-CODE ...)
# ; processing (DEFUN VTKRENDERERWINDOW-CODE ...)
# ; processing (DEFUN VTK-TERMINAL ...)
# ; processing (DEFUN LOOKUP-TABLE-EXISTS ...)
# ; processing (DEFUN COLOR-TRANSFORM-FUNCTION ...)
# ; processing (DEFUN CHECK-LOOKUP-TABLE ...)
# ; processing (DEFUN BUILD-SURFACE-GRID ...)
# ; processing (DEFUN VTK3D-CONE ...)
# ; processing (DEFUN ROTATE ...)
# ; processing (DEFUN VTK3D-PRISM ...)
# ; processing (DEFUN VTK3D-CYLINDER ...)
# ; processing (DEFUN VTK3D-CUBE ...)
# ; processing (DEFUN VTK3D-SPHERE ...)
# ; processing (DEFUN VTK3D-PARALLELOGRAM ...)
# ; processing (DEFUN VTK3D-TRIANGLE ...)
# ; processing (DEFUN VTK3D-VECTOR ...)
# ; processing (DEFUN VTK3D-POINTS ...)
# ; processing (DEFUN VTK2D-POINTS ...)
# ; processing (DEFUN VTK3D-PARAMETRIC ...)
# ; processing (DEFUN VTK2D-PARAMETRIC ...)
# ; processing (DEFUN VTK2D-POLAR ...)
# ; processing (DEFUN VTK3D-PARAMETRIC_SURFACE ...)
# ; processing (DEFUN VTK3D-SPHERICAL ...)
# ; processing (DEFUN VTK3D-CYLINDRICAL ...)
# ; processing (DEFUN VTK3D-EXPLICIT ...)
# ; processing (DEFUN VTK2D-EXPLICIT ...)
# ; processing (DEFUN VTK3D-ELEVATION_GRID ...)
# ; processing (DEFUN BUILD-SURFACE-TRIANGULAR-GRID ...)
# ; processing (DEFUN VTK3D-IMPLICIT ...)
# ; processing (DEFUN VTK3D-LABEL ...)
# ; processing (DEFMACRO VTK-CHECK-TUBE-EXTREME ...)
# ; processing (DEFUN VTK3D-TUBE ...)
# ; processing (DEFVAR *VTK2D-GRAPHIC-OBJECTS* ...)
# ; processing (SETF (GETHASH # ...) ...)
# ; processing (DEFUN MAKE-VTK-SCENE-2D ...)
# ; processing (DEFVAR *VTK3D-GRAPHIC-OBJECTS* ...)
# ; processing (SETF (GETHASH # ...) ...)
# ; processing (DEFUN MAKE-VTK-SCENE-3D ...)
# ; processing (DEFUN DRAW_VTK ...)SB-KERNEL:REDEFINITION-WITH-DEFMACRO: redefining MAXIMA::VTK-CHECK-TUBE-EXTREME in DEFMACRO
# ; processing (DEFUN CUT-AND-ROUND ...)
# ; processing (DEFUN $MAKE_LEVEL_PICTURE ...)
# ; processing (DEFUN $PICTUREP ...)
# ; processing (DEFUN $PICTURE_EQUALP ...)
# ; processing (DEFUN $MAKE_RGB_PICTURE ...)
# ; processing (DEFUN $TAKE_CHANNEL ...)
# ; processing (DEFUN $NEGATIVE_PICTURE ...)
# ; processing (DEFUN $RGB2LEVEL ...)
# ; processing (DEFUN $GET_PIXEL ...)
# ; processing (DEFVAR *XPM-READTABLE* ...)
# ; processing (DEFUN INIT-READTABLE ...)
# ; processing (DEFUN SKIP-WHITESPACE ...)
# ; processing (DEFUN READ-COLOUR ...)
# ; processing (DEFUN READ-CHARSPEC ...)
# ; processing (DEFUN READ-CSPEC ...)
# ; processing (DEFUN $READ_XPM ...)

# %% [markdown]
# ## `draw2d` Example

# %%
draw2d(explicit(((1+x)**2/(1+x*x))-1,x,-10,10))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxplot.svg.svg

# %% [markdown]
# ## `draw3d` Example

# %%
draw3d(
        colorbox   = "Magnitude",
        enhanced3d = true,
        explicit(x^2+y^2,x,-1,1,y,-1,1))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxplot.svg.svg

# %% [markdown]
# ## `draw` Example

# %%
draw(
    gr2d(
        key="sin (x)",grid=[2,2],
        explicit(
            sin(x),
            x,0,2*%pi
        )
    ),
    gr2d(
        key="cos (x)",grid=[2,2],
        explicit(
            cos(x),
            x,0,2*%pi
        )
    )
 )$

# %% [markdown]
# ## `animated_gif` Example

# %%
set_draw_defaults(terminal=animated_gif)$
sp(ang):=gr3d(enhanced3d = true,
        color      = green,
        logcb = true,
        logz  = true,
        palette = [-15,24,-9],
        view=[60,ang],
        explicit(exp(x^2-y^2), x,-2,2,y,-2,2))$
draw(delay=50,
    terminal = animated_gif,
    makelist(sp(mod(i, 360)),i,5,365,30))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.gif

# %% [markdown]
# # `descriptive` Plots
# First load `descriptive` and `distrib`.

# %%
load ("descriptive")$
load ("distrib")$
set_draw_defaults(terminal=svg)$

# %% [markdown]
# ## `barsplot` Example

# %%
l1:makelist(random(10),k,1,50)$
l2:makelist(random(10),k,1,100)$
barsplot(
        l1,l2,
        box_width    = 1,
        fill_density = 1,
        bars_colors  = [black, grey],
        frequency = relative,
        sample_keys = ["A", "B"])$

# %% [markdown]
# ## `boxplot` Example

# %%
s2 : read_matrix(file_search("wind.data"))$
boxplot(s2,
        box_width  = 0.2,
        title      = "Windspeed in knots",
        xlabel     = "Stations",
        color      = red,
        line_width = 2)$

# %% [markdown]
# ## `histogram` Example

# %%
s1 : read_list (file_search ("pidigits.data"))$
histogram (
           s1,
           nclasses     = 8,
           title        = "pi digits",
           xlabel       = "digits",
           ylabel       = "Absolute frequency",
           fill_color   = grey,
           fill_density = 0.6)$

# %% [markdown]
# ## `piechart` Example

# %%
piechart(
        s1,
        xrange  = [-1.1, 1.3],
        yrange  = [-1.1, 1.1],
        title   = "Digit frequencies in pi")$

# %% [markdown]
# ## `scatterplot` Example

# %%
s2 : read_matrix (file_search ("wind.data"))$
scatterplot(
       submatrix(s2, 1,2,3),
       title      = "Data from stations #4 and #5",
       point_type = diamant,
       point_size = 2,
       color      = blue)$

# %% [markdown]
# ## `starplot` Example

# %%
starplot(
        l1, l2,
        stars_colors = [blue,red],
        sample_keys = ["1st sample", "2nd sample"],
        star_center = [1,2],
        star_radius = 4,
        proportional_axes = xy,
        line_width = 2 ) $

# %% [markdown]
# ## `stemplot` Example

# %%
stemplot(
        random_normal(15, 6, 100),
        leaf_unit = 0.1)$

# %% [markdown]
# ## `implicit_plot` Example

# %%
load(implicit_plot)$

# %%
implicit_plot (x^2 = y^3 - 3*y + 1, [x, -4, 4], [y, -4, 4])$
