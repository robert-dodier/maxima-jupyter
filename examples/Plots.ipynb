# %% [markdown]
# The examples in this notebook were taken from the Maxima documentation.
#
# # Standard Plots
#
# First set the default plot options to SVG output so that Maxima-Jupyter can capture the output.

# %%
set_plot_option([svg_file, "maxplot.svg"])$

# %% [markdown]
# ## `contour_plot` Example

# %%
contour_plot (x^2 + y^2, [x, -4, 4], [y, -4, 4])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# ## `julia` Example

# %%
julia (-0.55, 0.6, [iterations, 36], [x, -0.3, 0.2],
      [y, 0.3, 0.9], [grid, 400, 400], [color_bar_tics, 0, 6, 36])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# ## `mandelbrot` Example

# %%
mandelbrot ([iterations, 30], [x, -2, 1], [y, -1.2, 1.2],
            [grid,400,400]);
# Out:
# /tmp/maxplot.svg
# (%o4)            [/tmp/maxout98234.gnuplot, /tmp/maxplot.svg]

# %% [markdown]
# ## `plot2d` Example

# %%
plot2d (sin(x), [x, -%pi, %pi])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# ## `plot3d` Example

# %%
plot3d (u^2 - v^2, [u, -2, 2], [v, -3, 3], [grid, 100, 100],
        [mesh_lines_color,false])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# # `draw` Plots
# First load the `draw` package and set the default terminal to `svg`.

# %%
load("draw")$
set_draw_defaults(file_name="maxplot.svg",terminal='svg)$

# %% [markdown]
# ## `draw2d` Example

# %%
draw2d(explicit(((1+x)**2/(1+x*x))-1,x,-10,10))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxplot.svg.svg

# %% [markdown]
# ## `draw3d` Example

# %%
draw3d(
        colorbox   = "Magnitude",
        enhanced3d = true,
        explicit(x^2+y^2,x,-1,1,y,-1,1))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxplot.svg.svg

# %% [markdown]
# ## `draw` Example

# %%
draw(
    gr2d(
        key="sin (x)",grid=[2,2],
        explicit(
            sin(x),
            x,0,2*%pi
        )
    ),
    gr2d(
        key="cos (x)",grid=[2,2],
        explicit(
            cos(x),
            x,0,2*%pi
        )
    )
 )$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxplot.svg.svg

# %% [markdown]
# ## `animated_gif` Example

# %%
set_draw_defaults(terminal=animated_gif)$
sp(ang):=gr3d(enhanced3d = true,
        color      = green,
        logcb = true,
        logz  = true,
        palette = [-15,24,-9],
        view=[60,ang],
        explicit(exp(x^2-y^2), x,-2,2,y,-2,2))$
draw(delay=50,
    terminal = animated_gif,
    makelist(sp(mod(i, 360)),i,5,365,30))$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.gif

# %% [markdown]
# # `descriptive` Plots
# First load `descriptive` and `distrib`.

# %%
load ("descriptive")$
load ("distrib")$
set_draw_defaults(terminal=svg)$

# %% [markdown]
# ## `barsplot` Example

# %%
l1:makelist(random(10),k,1,50)$
l2:makelist(random(10),k,1,100)$
barsplot(
        l1,l2,
        box_width    = 1,
        fill_density = 1,
        bars_colors  = [black, grey],
        frequency = relative,
        sample_keys = ["A", "B"])$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `boxplot` Example

# %%
s2 : read_matrix(file_search("wind.data"))$
boxplot(s2,
        box_width  = 0.2,
        title      = "Windspeed in knots",
        xlabel     = "Stations",
        color      = red,
        line_width = 2)$
# Out:
# ; processing (IN-PACKAGE :MAXIMA)
# ; processing (DEFUN SMASH-FLOAT-INTO-INTEGER ...)
# ; processing (DEFUN SMASH-DECODED-FLOAT-32-INTO-INTEGER ...)
# ; processing (DEFUN SMASH-DECODED-FLOAT-64-INTO-INTEGER ...)
# ; processing (DEFUN CONSTRUCT-FLOAT-64-FROM-INTEGER ...)
# ; processing (DEFUN EXTRACT-SMASHED-FLOAT-64-FROM-INTEGER ...)
# ; processing (DEFUN WRITE-FLOAT ...)
# ; processing (DEFUN SIZE-IN-BYTES ...)
# ; processing (DEFUN READ-FLOAT-64 ...)
# ; processing (DEFTYPE EXTERNAL-BYTE-ORDER ...)
# ; processing (DEFVAR *EXTERNAL-BYTE-ORDER* ...)
# ; processing (DEFUN DEFINE-EXTERNAL-BYTE-ORDER ...)
# ; processing (DEFUN READ-UNSIGNED-INTEGER ...)
# ; processing (DEFUN WRITE-UNSIGNED-INTEGER ...)
# ; processing (IN-PACKAGE :MAXIMA)
# ; processing (DEFUN $ASSUME_EXTERNAL_BYTE_ORDER ...)
# ; processing (DEFUN LISP-OR-DECLARED-MAXIMA-ARRAY-P ...)
# ; processing (DEFUN $OPENW_BINARY ...)
# ; processing (DEFUN $OPENA_BINARY ...)
# ; processing (DEFUN $OPENR_BINARY ...)
# ; processing (DEFUN $READ_MATRIX ...)
# ; processing (DEFUN $READ_BINARY_MATRIX ...)
# ; processing (DEFUN FILL-MATRIX-FROM-LIST ...)
# ; processing (DEFUN $READ_ARRAY ...)
# ; processing (DEFUN $READ_BINARY_ARRAY ...)
# ; processing (DEFUN READ-INTO-EXISTING-ARRAY ...)
# ; processing (DEFUN READ-INTO-EXISTING-ARRAY-SIZE-KNOWN ...)
# ; processing (DEFUN READ-INTO-EXISTING-ARRAY-SIZE-KNOWN-FROM-STREAM ...)
# ; processing (DEFUN READ-INTO-EXISTING-ARRAY-SIZE-UNKNOWN-FROM-STREAM ...)
# ; processing (DEFUN READ-AND-RETURN-NEW-ARRAY ...)
# ; processing (DEFUN READ-AND-RETURN-NEW-ARRAY-FROM-STREAM ...)
# ; processing (DEFUN $READ_HASHED_ARRAY ...)
# ; processing (DEFUN READ-HASHED-ARRAY-FROM-STREAM ...)
# ; processing (DEFUN $READ_NESTED_LIST ...)
# ; processing (DEFUN READ-NESTED-LIST-FROM-STREAM ...)
# ; processing (DEFUN $READ_LIST ...)
# ; processing (DEFUN READ-INTO-EXISTING-LIST ...)
# ; processing (DEFUN READ-INTO-EXISTING-LIST-FROM-STREAM ...)
# ; processing (DEFUN READ-LIST ...)
# ; processing (DEFUN READ-LIST-FROM-STREAM ...)
# ; processing (DEFUN $READ_BINARY_LIST ...)
# ; processing (DEFUN MAKE-MLIST-FROM-STRING ...)
# ; processing (DEFUN APPROPRIATE-APPEND ...)
# ; processing (DEFUN $READ_LISP_ARRAY ...)
# ; processing (DEFUN $READ_MAXIMA_ARRAY ...)
# ; processing (LET (PUSHBACK-SEP-CH) ...)
# ; processing (DEFUN OPEN-FILE-APPROPRIATELY ...)
# ; processing (DEFUN $WRITE_DATA ...)
# ; processing (DEFUN $WRITE_BINARY_DATA ...)
# ; processing (DEFUN WRITE-DATA ...)
# ; processing (DEFUN WRITE-MATRIX ...)
# ; processing (DEFUN WRITE-LISP-ARRAY ...)
# ; processing (DEFUN WRITE-LISP-ARRAY-HELPER ...)
# ; processing (DEFUN WRITE-MAXIMA-ARRAY ...)
# ; processing (DEFUN WRITE-HASHED-ARRAY ...)
# ; processing (DEFUN WRITE-LIST ...)
# ; processing (DEFUN WRITE-LIST-LOWLEVEL ...)
# ; processing (DEFUN GET-INPUT-SEP-CH ...)
# ; processing (DEFUN GET-OUTPUT-SEP-CH ...)
# ; processing (DEFUN REQUIRE-STRING ...)
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `histogram` Example

# %%
s1 : read_list (file_search ("pidigits.data"))$
histogram (
           s1,
           nclasses     = 8,
           title        = "pi digits",
           xlabel       = "digits",
           ylabel       = "Absolute frequency",
           fill_color   = grey,
           fill_density = 0.6)$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `piechart` Example

# %%
piechart(
        s1,
        xrange  = [-1.1, 1.3],
        yrange  = [-1.1, 1.1],
        title   = "Digit frequencies in pi")$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `scatterplot` Example

# %%
s2 : read_matrix (file_search ("wind.data"))$
scatterplot(
       submatrix(s2, 1,2,3),
       title      = "Data from stations #4 and #5",
       point_type = diamant,
       point_size = 2,
       color      = blue)$
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `starplot` Example

# %%
starplot(
        l1, l2,
        stars_colors = [blue,red],
        sample_keys = ["1st sample", "2nd sample"],
        star_center = [1,2],
        star_radius = 4,
        proportional_axes = xy,
        line_width = 2 ) $
# Out:
# /home/yitzi/Documents/git/maxima-jupyter/examples/maxima_out.svg

# %% [markdown]
# ## `stemplot` Example

# %%
stemplot(
        random_normal(15, 6, 100),
        leaf_unit = 0.1)$
# Out:
# key: 6|3 =  \(6.3\)
# -3|6
#  0|8
#  3|2
#  4|268
#  5|1389
#  6|012
#  7|4558
#  8|06
#  9|1356
# 10|057
# 11|0789
# 12|02335777899
# 13|011124666779
# 14|133469
# 15|0068
# 16|014566678899
# 17|01246
# 18|038
# 19|134477
# 20|559
# 21|5
# 22|1
# 24|444
# 25|6
# 26|8
# 27|8

# %% [markdown]
# ## `implicit_plot` Example

# %%
load(implicit_plot)$
# Out:
# [SB-KERNEL:REDEFINITION-WITH-DEFUN] redefining MAXIMA::CONTAINS-ZEROS in DEFUN
# [SB-KERNEL:REDEFINITION-WITH-DEFUN] redefining MAXIMA::SAMPLE-DATA in DEFUN
# [SB-KERNEL:REDEFINITION-WITH-DEFUN] redefining MAXIMA::IMP-PL-PREPARE-FACTOR in DEFUN
# [SB-KERNEL:REDEFINITION-WITH-DEFUN] redefining MAXIMA::IMP-PL-PREPARE-EXPR in DEFUN

# %%
implicit_plot (x^2 = y^3 - 3*y + 1, [x, -4, 4], [y, -4, 4])$
# Out:
# /tmp/maxplot.svg
